# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
import pandas as pd
import tensorflow as tf

# Import our input dataset
diabetes_df = pd.read_csv('/content/diabetes.csv')
diabetes_df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
# Remove diabetes outcome target from features data
y = diabetes_df.Outcome
X = diabetes_df.drop(columns="Outcome")

# Split training/test datasets
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, stratify=y)

# %%
# Preprocess numerical data for neural network

# Create a StandardScaler instance
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Define the logistic regression model
log_classifier = LogisticRegression(solver="lbfgs",max_iter=200)

# Train the model
log_classifier.fit(X_train,y_train)

# Evaluate the model
y_pred = log_classifier.predict(X_test)
print(f" Logistic regression model accuracy: {accuracy_score(y_test,y_pred):.3f}")
# Out:
#  Logistic regression model accuracy: 0.729

# %%
# Define the basic neural network model
nn_model = tf.keras.models.Sequential()
nn_model.add(tf.keras.layers.Dense(units=16, activation="relu", input_dim=8))

nn_model.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Compile the Sequential model together and customize metrics
nn_model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# Train the model
fit_model = nn_model.fit(X_train_scaled, y_train, epochs=50)

# Evaluate the model using the test data
model_loss, model_accuracy = nn_model.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# Epoch 1/50
# 18/18 [==============================] - 1s 2ms/step - loss: 0.6435 - accuracy: 0.6215
# Epoch 2/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.6068 - accuracy: 0.6788
# Epoch 3/50
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5767 - accuracy: 0.7066
# Epoch 4/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5524 - accuracy: 0.7257
# Epoch 5/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5335 - accuracy: 0.7396
# Epoch 6/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5177 - accuracy: 0.7587
# Epoch 7/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5052 - accuracy: 0.7726
# Epoch 8/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4950 - accuracy: 0.7726
# Epoch 9/50
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4868 - accuracy: 0.7760
# Epoch 10/50
# 18/18 [==============================] - 0s 4ms/step - loss: 0.4796 - accuracy: 0.7760
# Epoch 11/50
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4746 - accuracy: 0.7778
# Epoch 12/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4699 - accuracy: 0.7795
# Epoch 13/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4666 - accuracy: 0.7865
# Epoch 14/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4639 - accuracy: 0.7899
# Epoch 15/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4615 - accuracy: 0.7882
# Epoch 16/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4595 - accuracy: 0.7865
# Epoch 17/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4577 - accuracy: 0.7865
# Epoch 18/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4565 - accuracy: 0.7934
# Epoch 19/50
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4554 - accuracy: 0.7951
# Epoch 20/50
# 18/18 [==============================] - 0s 4ms/step - loss: 0.4546 - accuracy: 0.7951
# Epoch 21/50
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4537 - accuracy: 0.7934
# Epoch 22/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4532 - accuracy: 0.7934
# Epoch 23/50
# 18/18 [==============================] - 0s 4ms/step - loss: 0.4522 - accuracy: 0.7917
# Epoch 24/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4522 - accuracy: 0.7934
# Epoch 25/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4512 - accuracy: 0.7934
# Epoch 26/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4509 - accuracy: 0.7917
# Epoch 27/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4502 - accuracy: 0.7934
# Epoch 28/50
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4496 - accuracy: 0.7951
# Epoch 29/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4491 - accuracy: 0.7934
# Epoch 30/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4490 - accuracy: 0.7934
# Epoch 31/50
# 18/18 [==============================] - 0s 4ms/step - loss: 0.4486 - accuracy: 0.7951
# Epoch 32/50
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4477 - accuracy: 0.7951
# Epoch 33/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4476 - accuracy: 0.7934
# Epoch 34/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4472 - accuracy: 0.7951
# Epoch 35/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4467 - accuracy: 0.7951
# Epoch 36/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4465 - accuracy: 0.7951
# Epoch 37/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4457 - accuracy: 0.7969
# Epoch 38/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4456 - accuracy: 0.7951
# Epoch 39/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4451 - accuracy: 0.7969
# Epoch 40/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4447 - accuracy: 0.7986
# Epoch 41/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4442 - accuracy: 0.7969
# Epoch 42/50
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4438 - accuracy: 0.7969
# Epoch 43/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4437 - accuracy: 0.7951
# Epoch 44/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4431 - accuracy: 0.7951
# Epoch 45/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4428 - accuracy: 0.7969
# Epoch 46/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4429 - accuracy: 0.7986
# Epoch 47/50
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4422 - accuracy: 0.7969
# Epoch 48/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4417 - accuracy: 0.7969
# Epoch 49/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4412 - accuracy: 0.7986
# Epoch 50/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4410 - accuracy: 0.7986
# 6/6 - 0s - loss: 0.4886 - accuracy: 0.7240 - 201ms/epoch - 33ms/step
# Loss: 0.4886139929294586, Accuracy: 0.7239583134651184

# %%
model_loss, model_accuracy= nn_model.evaluate(X_test_scaled,y_test)

print( model_accuracy)
# Out:
# 6/6 [==============================] - 0s 4ms/step - loss: 0.4789 - accuracy: 0.7344
# 0.734375
